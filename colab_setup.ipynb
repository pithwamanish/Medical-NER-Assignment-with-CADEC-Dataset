# %% [markdown]
# # CADEC NER Project - Google Colab Setup
#
# This notebook sets up the CADEC NER project in Google Colab.
#
# ## Choose Your Method:
# - **Using Git?** → Skip to "Step 2: Git Setup" (Recommended)
# - **Using Google Drive?** → Use "Step 1: Google Drive Setup"

# %% [markdown]
# ## Step 1: Git Setup (Recommended - If using Git)
#
# **If you're already using git pull, start here!**
#
# Update `REPO_PATH` with your repository path.

# %%
import os
import sys

# Update this with your repository path
REPO_PATH = '/content/Medical-NER-Assignment-with-CADEC-Dataset'  # Change this!

# If first time, clone:
# !git clone https://github.com/yourusername/your-repo.git

# If already cloned, pull latest changes:
if os.path.exists(REPO_PATH):
    os.chdir(REPO_PATH)
    # !git pull
else:
    print(f"⚠️ Repository not found at {REPO_PATH}")
    print("Please clone it first or update REPO_PATH")

os.chdir(REPO_PATH)
sys.path.insert(0, os.getcwd())
print(f"✅ Current directory: {os.getcwd()}")

# %% [markdown]
# ## Step 3: Install Dependencies

# %%
# !pip install -q -r requirements.txt
print("✅ Dependencies installed")

# %% [markdown]
# ## Step 4: Test Imports

# %%
try:
    import config
    from src.utils.logging_utils import setup_logging
    from src.data_loader import load_ground_truth
    print("✅ All imports successful!")
except Exception as e:
    print(f"❌ Import error: {e}")
    import traceback
    traceback.print_exc()

# %% [markdown]
# ## Step 5: Setup Logging

# %%
from src.utils.logging_utils import setup_logging
setup_logging()
print("✅ Logging configured")
